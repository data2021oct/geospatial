# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map, TileLayer
from folium.plugins import HeatMap, MarkerCluster
import geopandas as gpd
import pandas as pd

# %%
 localizations = {'Austin': ['30.27125853189173', '-97.75551842126049'],
 'Hamburg': ['53.55687309076416', '10.002900693677232'],
 'Newcastle': ['54.96923892979405', '-1.6162802662146134']}

# %%
venues_df = pd.read_csv("../data/venues_df.csv")

# %%
Austin_df = venues_df[venues_df["city"] == "Austin"].sort_values(["category","distance"])
Austin_df.head(3)
# Out:
#        nombre sub_category    latitud   longitud  distance  \
# 46  Starbucks  Coffee Shop  30.269783 -97.753914       225
# 47  Starbucks  Coffee Shop  30.265858 -97.746308      1070
# 48  Starbucks  Coffee Shop  30.261259 -97.757964      1137
#
#                                              location    city     category  \
# 46  {'type': 'Point', 'coordinates': [30.269783, -...  Austin  Coffee Shop
# 47  {'type': 'Point', 'coordinates': [30.265857567...  Austin  Coffee Shop
# 48  {'type': 'Point', 'coordinates': [30.261258698...  Austin  Coffee Shop
#
#     ponder                                      geometry
# 46       7          POINT (-97.75391399999999 30.269783)
# 47       7   POINT (-97.7463083781941 30.26585756712895)
# 48       7  POINT (-97.75796442738695 30.26125869874164)

# %%
aus_lat = localizations["Austin"][0]
aus_lon = localizations["Austin"][1]

# %%
map_aus = folium.Map(location=[aus_lat,aus_lon], zoom_start=15)

# %%
Austin_df.category.unique()
# Out:
# array(['Coffee Shop', 'Design Studio', 'Dobby', 'Nightlife Spot',
#        'School', 'Tech Startup', 'Train Station',
#        'Vegetarian / Vegan Restaurant'], dtype=object)

# %%
icono = Icon(color="white",
             prefix = "fa",
             icon="building ",
             icon_color="black",)
marker_uno = Marker(location=[aus_lat, aus_lon], tooltip = "OFFICE", icon=icono)
marker_uno.add_to(map_aus)

# %%
for i,row in Austin_df.iterrows():
    cat = {"location": [row["latitud"], row["longitud"]], "tooltip": row["category"]}
    
    if row["category"] == "School" :
        icono = Icon(color = "red",
                     prefix="fa",
                     icon="child",
                     icon_color="black" )
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)
        
    elif row["category"] == "Coffee Shop":
        icono = Icon(color = "beige",
                     prefix="fa",
                     icon="coffee",
                     icon_color="black")
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)
        
    elif row["category"] == "Dobby" :
        icono = Icon(color = "green",
                     prefix="fa",
                     icon="paw",
                     icon_color="black")
        
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)
   
    elif row["category"] == "Basketball Stadium" :
        icono = Icon(color = "blue",
                     prefix="fa",
                     icon="futbol-o",
                     icon_color="black")
        
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)
    
    elif row["category"] == "Design Studio" :
        icono = Icon(color = "orange",
                     prefix="fa",
                     icon="pencil",
                     icon_color="black")
        
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)
    
    elif row["category"] == "Nightlife Spot" :
        icono = Icon(color = "black",
                     prefix="fa",
                     icon="glass",
                     icon_color="white")
        
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)
    
    elif row["category"] == "Tech Startup" :
        icono = Icon(color = "gray",
                     prefix="fa",
                     icon="laptop",
                     icon_color="white")
        
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)
        
    elif row["category"] == "Vegetarian / Vegan Restaurant" :
        icono = Icon(color = "purple",
                     prefix="fa",
                     icon="leaf",
                     icon_color="black")
        
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)

    elif row["category"] == "Train Station" :
        icono = Icon(color = "pink",
                     prefix="fa",
                     icon="train",
                     icon_color="black")
        
        mark = Marker(**cat, icon=icono)
        mark.add_to(map_aus)

# %%
map_aus
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_fc3864635d5f41eeae9eaf5ac8c0fe4c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_fc3864635d5f41eeae9eaf5ac8c0fe4c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_fc3864635d5f41eeae9eaf5ac8c0fe4c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_fc3864635d5f41eeae9eaf5ac8c0fe4c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B30.27125853189173%2C%20-97.75551842126049%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...
